# %%
from diabetes_model import DiabetesModel
url = "https://github.com/francomar95/Topologia3A/blob/38d5753bf696fea5de6dc9db73041d26a51ffa9a/diabetes.csv?raw=true"
model = DiabetesModel(url)
model.plot_heatmap()
model.plot_scatter()
model.plot_regression('glucosa', 'diabetes')
model.plot_regression('imc', 'diabetes')
X_test, y_test, predicciones = model.train_logistic_regression()
model.logistic_regression_metrics(X_test, y_test, predicciones)
model.train_linear_regression()
model.predict_new_data()
# Out:
# Precisión del modelo: 0.7662337662337663
# Coeficientes de la regresión logística:
# Intercepto: [-0.82437897]
# Coeficientes: [[0.6547683  1.09673749]]
# Matriz de confusión:
#  [[84 15]
#  [21 34]]
# AUC-ROC: 0.8088154269972452
# Puntajes de validación cruzada: [0.77272727 0.73376623 0.76623377 0.78431373 0.73856209]
# Puntaje medio de validación cruzada: 0.7591206179441474
# Modelo de Regresión:
# Intercepto (beta_0): 25.402116839076637
# Coeficiente de X (beta_1): 0.05451413904153221
# Error cuadrático medio (MSE): 59.04509338515581
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9f3e86fd74f4> in <cell line: 2>()
#       1 # Importa la clase desde el archivo diabetes_model.py
# ----> 2 from diabetes_model import DiabetesModel
#       3
#       4 # Define la URL del nuevo conjunto de datos
#       5 url = "https://github.com/francomar95/Topologia3A/blob/38d5753bf696fea5de6dc9db73041d26a51ffa9a/diabetes.csv?raw=true"
#
# /content/diabetes_model.py in <module>
#     147
#     148 # Llamada al nuevo método de predicción
# --> 149 model.predict_new_data()
#
# /content/diabetes_model.py in predict_new_data(self)
#     122
#     123     def predict_new_data(self):
# --> 124         nueva_glucosa = float(input("Introduce el nivel de glucosa: "))
#     125         nuevo_imc = float(input("Introduce el IMC: "))
#     126         nuevo_dato = self.scaler.transform([[nuevo_imc, nueva_glucosa]])
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
